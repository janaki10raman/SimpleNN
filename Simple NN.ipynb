# %% [markdown]
# # Simple NN to predict the Patient is Diabetic or not.

# %%
import sys
import pandas as pd
import numpy as np
from numpy import loadtxt
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import models
# Out:
# Using TensorFlow backend.

# %%
#Loading the dataset
dataset=pd.read_csv('diabetesclean.csv')
dataset.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
data=loadtxt('diabetesclean.csv',delimiter=',')

# %%
data
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
data.shape
# Out:
# (768, 9)

# %%
x=data[:,0:8]#n-1
y=data[:,8]

# %%
#Spliting the data to train and test.
xtrain, xtest, ytrain, ytest=train_test_split(x,y,test_size=0.2)

# %%
#Creating the Model
model=Sequential()

# %%
model.add(Dense(12,input_dim=8,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 12)                108
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# ...
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(xtrain,ytrain,epochs=100,batch_size=20)
# Out:
# Epoch 1/100
# 614/614 [==============================] - 0s 732us/step - loss: 2.5570 - accuracy: 0.5342
# Epoch 2/100
# 614/614 [==============================] - 0s 61us/step - loss: 1.4685 - accuracy: 0.5733
# Epoch 3/100
# 614/614 [==============================] - 0s 57us/step - loss: 1.2523 - accuracy: 0.5651
# Epoch 4/100
# 614/614 [==============================] - 0s 59us/step - loss: 1.0865 - accuracy: 0.5782
# Epoch 5/100
# 614/614 [==============================] - 0s 66us/step - loss: 0.9820 - accuracy: 0.6059
# Epoch 6/100
# 614/614 [==============================] - 0s 63us/step - loss: 0.8760 - accuracy: 0.6042
# Epoch 7/100
# 614/614 [==============================] - 0s 67us/step - loss: 0.7744 - accuracy: 0.6401
# Epoch 8/100
# 614/614 [==============================] - 0s 60us/step - loss: 0.7409 - accuracy: 0.6547
# Epoch 9/100
# 614/614 [==============================] - 0s 65us/step - loss: 0.6955 - accuracy: 0.6417
# Epoch 10/100
# ...

# %%
#Finding the Accuracy
_,accuracy=model.evaluate(xtest,ytest)
print(accuracy)
# Out:
# 154/154 [==============================] - 0s 150us/step
# 0.7467532753944397

# %%
inputa=np.array([[1,85,66,29,0,26.6,0.351,31]])

# %%
inputa.shape
# Out:
# (1, 8)

# %%
output=model.predict(inputa)
output
# Out:
# array([[0.1260688]], dtype=float32)
